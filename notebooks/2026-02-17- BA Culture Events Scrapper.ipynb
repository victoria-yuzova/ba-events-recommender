# %% [markdown]
# # Buenos Aires Cultural Events Dataset
#
# ### BUSINESS CHALLENGE:
#
# Create a product that allows us to see a quick view of current cultural events in Buenos Aires classified by type of event and venue. It should provide information about all events and related links from different venues in Buenos Aires, so we can easily pick what we want to do this week.

# %%
import os
print("cwd:", os.getcwd())
print("src exists:", os.path.exists(os.path.abspath("../src")))
print("scraper exists:", os.path.exists(os.path.abspath("../src/scraper.py")))
# Out:
# cwd: /Users/victoriayuzova/Data-Science-Projects/ba-events-recommender/notebooks
# src exists: True
# scraper exists: True

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt
import os
import sys
import json
import importlib

from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# Force the notebook to import the *local* ../src/scraper.py (not the pip package named `scraper`)
src_path = os.path.abspath("../src")
if src_path not in sys.path:
    sys.path.insert(0, src_path)
if "scraper" in sys.modules:
    del sys.modules["scraper"]

scraper = importlib.import_module("scraper")
fetch_website_links = scraper.fetch_website_links
fetch_website_contents = scraper.fetch_website_contents

# %%
homepage_urls = [
    "https://complejoteatral.gob.ar/",
    "https://malba.org.ar/",
    "https://www.teatrocervantes.gob.ar/",
    "https://turismo.buenosaires.gob.ar/es/article/que-hacer-esta-semana",
    "https://www.bellasartes.gob.ar/agenda/",
]

# %%
import pandas as pd

rows = []
for page_url in homepage_urls:
    event_url = fetch_website_links(page_url)
    rows.extend([{"page_url": page_url, "event_url": url} for url in event_url])
df = pd.DataFrame(rows)
df.head()
# Out:
#                           page_url  \
# 0  https://complejoteatral.gob.ar/
# 1  https://complejoteatral.gob.ar/
# 2  https://complejoteatral.gob.ar/
# 3  https://complejoteatral.gob.ar/
# 4  https://complejoteatral.gob.ar/
#
#                                            event_url
# 0                     https://complejoteatral.gob.ar
# 1                         http://buenosaires.gob.ar/
# 2                                      #programacion
# 3  https://complejoteatral.gob.ar/agenda?fecha=18...
# 4  https://complejoteatral.gob.ar/pdf/temporada20...

# %%
df.describe()
# Out:
#                      page_url event_url
# count                     576       576
# unique                      5       297
# top     https://malba.org.ar/         #
# freq                      187        38

# %%
df = df.drop_duplicates(subset=["page_url", "event_url"]).reset_index(drop=True)

# %%
df
# Out:
#                                    page_url  \
# 0           https://complejoteatral.gob.ar/
# 1           https://complejoteatral.gob.ar/
# 2           https://complejoteatral.gob.ar/
# 3           https://complejoteatral.gob.ar/
# 4           https://complejoteatral.gob.ar/
# ..                                      ...
# 296  https://www.bellasartes.gob.ar/agenda/
# 297  https://www.bellasartes.gob.ar/agenda/
# 298  https://www.bellasartes.gob.ar/agenda/
# 299  https://www.bellasartes.gob.ar/agenda/
# 300  https://www.bellasartes.gob.ar/agenda/
#
#                                              event_url
# 0                       https://complejoteatral.gob.ar
# 1                           http://buenosaires.gob.ar/
# 2                                        #programacion
# 3    https://complejoteatral.gob.ar/agenda?fecha=18...
# 4    https://complejoteatral.gob.ar/pdf/temporada20...
# ..                                                 ...
# 296                                     /publicaciones
# 297                        /cdn-cgi/l/email-protection
# 298        https://museoartedecorativo.cultura.gob.ar/
# 299     https://museohistoriconacional.cultura.gob.ar/
# 300                http://museodeltraje.cultura.gob.ar
#
# [301 rows x 2 columns]

# %%
mask = ~df["event_url"].astype(str).str.match(r"^https?://", na=False)
df[mask][["page_url", "event_url"]]
# Out:
#                                    page_url  \
# 2           https://complejoteatral.gob.ar/
# 8           https://complejoteatral.gob.ar/
# 13          https://complejoteatral.gob.ar/
# 14          https://complejoteatral.gob.ar/
# 15          https://complejoteatral.gob.ar/
# ..                                      ...
# 293  https://www.bellasartes.gob.ar/agenda/
# 294  https://www.bellasartes.gob.ar/agenda/
# 295  https://www.bellasartes.gob.ar/agenda/
# 296  https://www.bellasartes.gob.ar/agenda/
# 297  https://www.bellasartes.gob.ar/agenda/
#
#                                              event_url
# 2                                        #programacion
# 8    /cdn-cgi/l/email-protection#ddb4b3bbb29dbeb2b0...
# 13                            /agenda?fecha=18-02-2026
# 14                                          /noticias/
# 15                                                   #
# ..                                                 ...
# 293                         /coleccion/arte-argentino/
# 294                         /coleccion/obras-maestras/
# 295                                          /noticias
# 296                                     /publicaciones
# 297                        /cdn-cgi/l/email-protection
#
# [90 rows x 2 columns]

# %%
# drop anchors + cloudflare email protection
df = df[~df["event_url"].astype(str).str.startswith("#", na=False)]
df = df[~df["event_url"].astype(str).str.contains("cdn-cgi/l/email-protection", na=False)]

# %%
df.describe()
df.head()
df.tail()
df.info()
df.isnull().sum()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 284 entries, 0 to 300
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   page_url   284 non-null    object
#  1   event_url  284 non-null    object
# dtypes: object(2)
# memory usage: 6.7+ KB
# page_url     0
# event_url    0
# dtype: int64

# %%
pd.set_option("display.max_rows", 200)      # or None (careful)
pd.set_option("display.max_colwidth", None)
df
# Out:
#                                    page_url  \
# 0           https://complejoteatral.gob.ar/
# 1           https://complejoteatral.gob.ar/
# 3           https://complejoteatral.gob.ar/
# 4           https://complejoteatral.gob.ar/
# 5           https://complejoteatral.gob.ar/
# ..                                      ...
# 295  https://www.bellasartes.gob.ar/agenda/
# 296  https://www.bellasartes.gob.ar/agenda/
# 298  https://www.bellasartes.gob.ar/agenda/
# 299  https://www.bellasartes.gob.ar/agenda/
# 300  https://www.bellasartes.gob.ar/agenda/
#
#                                                                    event_url
# 0                                             https://complejoteatral.gob.ar
# 1                                                 http://buenosaires.gob.ar/
# 3                     https://complejoteatral.gob.ar/agenda?fecha=18-02-2026
# 4                       https://complejoteatral.gob.ar/pdf/temporada2026.pdf
# 5    https://complejoteatral.gob.ar/ver/visitas_guiadas_al_teatro_san_martín
# ..                                                                       ...
# 295                                                                /noticias
# 296                                                           /publicaciones
# 298                              https://museoartedecorativo.cultura.gob.ar/
# 299                           https://museohistoriconacional.cultura.gob.ar/
# 300                                      http://museodeltraje.cultura.gob.ar
#
# [284 rows x 2 columns]

# %%
df.to_csv("links.csv", index=False)

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Default model you can use elsewhere
MODEL = 'gpt-5-nano'

# Use a steadier model for link selection (avoid long hangs/timeouts)
LINK_MODEL = 'gpt-4.1-mini'

# Add a client-side timeout so a single slow request doesn't hang the notebook
openai = OpenAI(timeout=180)

# %%
import re
from urllib.parse import urljoin, urldefrag

df2 = df.copy()
df2["event_url"] = df2["event_url"].astype(str).str.strip()
df2 = df2[df2["event_url"].ne("")]

# normalize relative -> absolute + drop fragments (#...)
def normalize(row):
    u = row["event_url"]
    if not re.match(r"^https?://", u):
        u = urljoin(row["page_url"], u)
    u, _frag = urldefrag(u)
    return u

df2["event_url"] = df2.apply(normalize, axis=1)

# drop obvious junk
drop_pat = r"(cdn-cgi/l/email-protection|^javascript:|instagram\.com|facebook\.com|x\.com|twitter\.com|youtube\.com|tiktok\.com|flickr\.com|politicas-de-privacidad|aviso-legal|privacy|terms|cookies|/contacto/?$)"
df2 = df2[~df2["event_url"].str.contains(drop_pat, case=False, na=False)]

# keep likely event pages (adjust as you learn)
keep_pat = r"(/agenda|/evento/|/eventos/|/obra/|/calendario|/programacion|/proximamente|/ver/|/pdf/|entradasba\.buenosaires\.gob\.ar/evento/)"
df2 = df2[df2["event_url"].str.contains(keep_pat, case=False, na=False)]

df2 = df2.drop_duplicates(subset=["page_url", "event_url"]).reset_index(drop=True)
df2
# Out:
# /var/folders/6t/ss4jn8_x3bx5gzn4fh3r10g00000gn/T/ipykernel_93405/2215300158.py:20: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df2 = df2[~df2["event_url"].str.contains(drop_pat, case=False, na=False)]
# /var/folders/6t/ss4jn8_x3bx5gzn4fh3r10g00000gn/T/ipykernel_93405/2215300158.py:24: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df2 = df2[df2["event_url"].str.contains(keep_pat, case=False, na=False)]
#                                   page_url  \
# 0          https://complejoteatral.gob.ar/
# 1          https://complejoteatral.gob.ar/
# 2          https://complejoteatral.gob.ar/
# 3          https://complejoteatral.gob.ar/
# 4          https://complejoteatral.gob.ar/
# 5          https://complejoteatral.gob.ar/
# 6          https://complejoteatral.gob.ar/
# 7          https://complejoteatral.gob.ar/
# 8          https://complejoteatral.gob.ar/
# 9          https://complejoteatral.gob.ar/
# 10         https://complejoteatral.gob.ar/
# 11         https://complejoteatral.gob.ar/
# 12         https://complejoteatral.gob.ar/
# 13         https://complejoteatral.gob.ar/
# 14         https://complejoteatral.gob.ar/
# 15         https://complejoteatral.gob.ar/
# 16         https://complejoteatral.gob.ar/
# 17         https://complejoteatral.gob.ar/
# 18         https://complejoteatral.gob.ar/
# 19         https://complejoteatral.gob.ar/
# 20         https://complejoteatral.gob.ar/
# 21         https://complejoteatral.gob.ar/
# 22         https://complejoteatral.gob.ar/
# 23         https://complejoteatral.gob.ar/
# 24         https://complejoteatral.gob.ar/
# 25         https://complejoteatral.gob.ar/
# 26         https://complejoteatral.gob.ar/
# 27         https://complejoteatral.gob.ar/
# 28         https://complejoteatral.gob.ar/
# 29         https://complejoteatral.gob.ar/
# 30         https://complejoteatral.gob.ar/
# 31         https://complejoteatral.gob.ar/
# 32         https://complejoteatral.gob.ar/
# 33         https://complejoteatral.gob.ar/
# 34         https://complejoteatral.gob.ar/
# 35         https://complejoteatral.gob.ar/
# 36                   https://malba.org.ar/
# 37                   https://malba.org.ar/
# 38                   https://malba.org.ar/
# 39                   https://malba.org.ar/
# 40                   https://malba.org.ar/
# 41                   https://malba.org.ar/
# 42                   https://malba.org.ar/
# 43                   https://malba.org.ar/
# 44                   https://malba.org.ar/
# 45                   https://malba.org.ar/
# 46                   https://malba.org.ar/
# 47                   https://malba.org.ar/
# 48                   https://malba.org.ar/
# 49                   https://malba.org.ar/
# 50                   https://malba.org.ar/
# 51                   https://malba.org.ar/
# 52                   https://malba.org.ar/
# 53                   https://malba.org.ar/
# 54                   https://malba.org.ar/
# 55     https://www.teatrocervantes.gob.ar/
# 56     https://www.teatrocervantes.gob.ar/
# 57     https://www.teatrocervantes.gob.ar/
# 58     https://www.teatrocervantes.gob.ar/
# 59     https://www.teatrocervantes.gob.ar/
# 60     https://www.teatrocervantes.gob.ar/
# 61     https://www.teatrocervantes.gob.ar/
# 62  https://www.bellasartes.gob.ar/agenda/
# 63  https://www.bellasartes.gob.ar/agenda/
# 64  https://www.bellasartes.gob.ar/agenda/
# 65  https://www.bellasartes.gob.ar/agenda/
# 66  https://www.bellasartes.gob.ar/agenda/
# 67  https://www.bellasartes.gob.ar/agenda/
# 68  https://www.bellasartes.gob.ar/agenda/
# 69  https://www.bellasartes.gob.ar/agenda/
# 70  https://www.bellasartes.gob.ar/agenda/
# 71  https://www.bellasartes.gob.ar/agenda/
# 72  https://www.bellasartes.gob.ar/agenda/
# 73  https://www.bellasartes.gob.ar/agenda/
# 74  https://www.bellasartes.gob.ar/agenda/
# 75  https://www.bellasartes.gob.ar/agenda/
# 76  https://www.bellasartes.gob.ar/agenda/
# 77  https://www.bellasartes.gob.ar/agenda/
# 78  https://www.bellasartes.gob.ar/agenda/
# 79  https://www.bellasartes.gob.ar/agenda/
# 80  https://www.bellasartes.gob.ar/agenda/
# 81  https://www.bellasartes.gob.ar/agenda/
#
#                                                                                                         event_url
# 0                                                          https://complejoteatral.gob.ar/agenda?fecha=18-02-2026
# 1                                                            https://complejoteatral.gob.ar/pdf/temporada2026.pdf
# 2                                         https://complejoteatral.gob.ar/ver/visitas_guiadas_al_teatro_san_martín
# 3                                                                   https://complejoteatral.gob.ar/ver/la_gaviota
# 4                               https://entradasba.buenosaires.gob.ar/evento/d90f82ed-ec8f-46cf-b8b2-48e665a36fc3
# 5                                                   https://complejoteatral.gob.ar/ver/los-pilares-de-la-sociedad
# 6                               https://entradasba.buenosaires.gob.ar/evento/42523311-973e-4a52-b2ee-63a59c48a2b7
# 7                                                                  https://complejoteatral.gob.ar/ver/baco-polaco
# 8                               https://entradasba.buenosaires.gob.ar/evento/f94c1c9a-151e-49a8-8ed8-c9aa9d0464c3
# 9                                                                 https://complejoteatral.gob.ar/ver/invasiones-1
# 10                              https://entradasba.buenosaires.gob.ar/evento/e1281314-a634-47a0-a2fa-89f0c3c88b0b
# 11                                                             https://complejoteatral.gob.ar/ver/buenas-palabras
# 12                              https://entradasba.buenosaires.gob.ar/evento/67826298-9dd3-4680-bf3f-d3d652a513c0
# 13                                                                 https://complejoteatral.gob.ar/ver/chau-macoco
# 14                                                           https://complejoteatral.gob.ar/ver/jazz_buenos_aires
# 15                                                        https://complejoteatral.gob.ar/ver/festival_el_tornillo
# 16                                                          https://complejoteatral.gob.ar/ver/MILONGA-EN-EL-HALL
# 17                                                         https://complejoteatral.gob.ar/ver/milonga_en_el_plata
# 18                                                        https://complejoteatral.gob.ar/ver/boleslaw-senderowicz
# 19                              https://entradasba.buenosaires.gob.ar/evento/b1e874ee-2bed-4b60-886b-2fb3ff16cbf5
# 20                                              https://complejoteatral.gob.ar/ver/La-semana-de-los-muertos-vivos
# 21                                          https://complejoteatral.gob.ar/pdf/la-semana-de-los-muertos-vivos.pdf
# 22                              https://entradasba.buenosaires.gob.ar/evento/56560ce9-5a8d-425d-b927-242b1f96b1c1
# 23                                                           https://complejoteatral.gob.ar/ver/Tardes-de-soledad
# 24                                              https://complejoteatral.gob.ar/pdf/programa-tardes-de-soledad.pdf
# 25                              https://entradasba.buenosaires.gob.ar/evento/8d95c637-802f-4f2a-95bc-c4cb9b4a7459
# 26                                  https://complejoteatral.gob.ar/ver/Semana-de-los-Premios-Goya-en-Buenos-Aires
# 27                              https://complejoteatral.gob.ar/pdf/semana-de-los-premios-goya-en-buenos-aires.pdf
# 28                              https://entradasba.buenosaires.gob.ar/evento/18bbe55b-23d0-4526-a64f-be6ba06afa35
# 29                                                         https://complejoteatral.gob.ar/ver/ Cinemateca-abierta
# 30                                        https://complejoteatral.gob.ar/pdf/programa-cinemateca-abierta-2026.pdf
# 31                                        https://complejoteatral.gob.ar/ver/Cien-años-atrás:-aventuras-y-romance
# 32                                           https://complejoteatral.gob.ar/pdf/programa-cien-anos-atras-2026.pdf
# 33                                    https://complejoteatral.gob.ar/ver/Nicolás-Pereda:-el-pensamiento-en-acción
# 34                                                                  https://complejoteatral.gob.ar/ver/En-el-cine
# 35                                                        https://www.paseolaplaza.com.ar/obra/queridisimo-truman
# 36                                                                               https://malba.org.ar/agenda-hoy/
# 37                                                                    https://malba.org.ar/eventos/sobre/virtual/
# 38                                         https://malba.org.ar/evento/tercer-ojo__coleccion-costantini_en-malba/
# 39                                  https://malba.org.ar/evento/margarita-paksa-ideas-correspondientes-1964-1984/
# 40                                                      https://malba.org.ar/evento/olga-de-amaral-cuerpo-textil/
# 41                                             https://malba.org.ar/evento/fernanda-laguna-mi-corazon-es-un-iman/
# 42                                                                     https://malba.org.ar/evento/cuerpo-textil/
# 43                                             https://malba.org.ar/evento/borges-entre-el-tiempo-y-la-eternidad/
# 44                               https://malba.org.ar/evento/visitas-guiadas__recorridos-abiertos-por-tercer-ojo/
# 45                             https://malba.org.ar/evento/margarita-x-margarita-textos-hablados-textos-escritos/
# 46                                                   https://malba.org.ar/evento/recorrido-en-lsa-por-tercer-ojo/
# 47                                                                     https://malba.org.ar/evento/the-souffleur/
# 48                                                                             https://malba.org.ar/evento/weser/
# 49                                                                    https://malba.org.ar/evento/un-cabo-suelto/
# 50                                                            https://malba.org.ar/evento/caripelas-de-coleccion/
# 51  https://malba.org.ar/evento/el-limite-de-lo-humano-virginia-woolf-stanislaw-lem-haruki-murakami-y-w-g-sebald/
# 52        https://malba.org.ar/evento/recorridos-abiertos-por-pop-brasil-vanguardia-y-nueva-figuracion-1960s-70s/
# 53               https://malba.org.ar/evento/micro-mediaciones__margarita-paksa-ideas-correspondientes-1964-1984/
# 54                                                                              https://malba.org.ar/evento/ls83/
# 55                                                               https://www.teatrocervantes.gob.ar/proximamente/
# 56                                                    https://www.teatrocervantes.gob.ar/obra/el-retrato-punzo-2/
# 57                                                    https://www.teatrocervantes.gob.ar/obra/los-dias-perfectos/
# 58                                            https://www.teatrocervantes.gob.ar/obra/la-revista-del-cervantes-3/
# 59                                                                 https://www.teatrocervantes.gob.ar/calendario/
# 60                                                   https://www.teatrocervantes.gob.ar/obra/el-avido-espectador/
# 61                                                               https://www.teatrocervantes.gob.ar/programacion/
# 62                                                                         https://www.bellasartes.gob.ar/agenda/
# 63                                                          https://www.bellasartes.gob.ar/lang/pt/?path=/agenda/
# 64                                                          https://www.bellasartes.gob.ar/lang/en/?path=/agenda/
# 65                                                                https://www.bellasartes.gob.ar/agenda/2026/2/3/
# 66                                                                https://www.bellasartes.gob.ar/agenda/2026/3/5/
# 67                            https://www.bellasartes.gob.ar/agenda/circulacion-en-planta-baja-con-sentido-unico/
# 68                                                            https://www.bellasartes.gob.ar/agenda/visit-egipto/
# 69                                                         https://www.bellasartes.gob.ar/agenda/rituales-egipto/
# 70                                                               https://www.bellasartes.gob.ar/agenda/arte-arg1/
# 71                                                              https://www.bellasartes.gob.ar/agenda/exp-egipto/
# 72                                                               https://www.bellasartes.gob.ar/agenda/premio-25/
# 73                                                           https://www.bellasartes.gob.ar/agenda/dibujo-egipto/
# 74                                                            https://www.bellasartes.gob.ar/agenda/letras-egipt/
# 75                                                        https://www.bellasartes.gob.ar/agenda/desafios-sigloxx/
# 76                              https://www.bellasartes.gob.ar/agenda/recorrido-por-la-planta-baja-y-primer-piso/
# 77                                                          https://www.bellasartes.gob.ar/agenda/visit-egipto-2/
# 78                                                                   https://www.bellasartes.gob.ar/agenda/azull/
# 79                                                    https://www.bellasartes.gob.ar/agenda/encuentro-literatura/
# 80                                                              https://www.bellasartes.gob.ar/agenda/lsa-egipto/
# 81                                                            https://www.bellasartes.gob.ar/agenda/guardar-como/

# %%
grouped = df2.groupby("page_url")["event_url"].apply(list)
grouped
# Out:
# page_url
# https://complejoteatral.gob.ar/           [https://complejoteatral.gob.ar/agenda?fecha=18-02-2026, https://complejoteatral.gob.ar/pdf/temporada2026.pdf, https://complejoteatral.gob.ar/ver/visitas_guiadas_al_teatro_san_martín, https://complejoteatral.gob.ar/ver/la_gaviota, https://entradasba.buenosaires.gob.ar/evento/d90f82ed-ec8f-46cf-b8b2-48e665a36fc3, https://complejoteatral.gob.ar/ver/los-pilares-de-la-sociedad, https://entradasba.buenosaires.gob.ar/evento/42523311-973e-4a52-b2ee-63a59c48a2b7, https://complejoteatral.gob.ar/ver/baco-polaco, https://entradasba.buenosaires.gob.ar/evento/f94c1c9a-151e-49a8-8ed8-c9aa9d0464c3, https://complejoteatral.gob.ar/ver/invasiones-1, https://entradasba.buenosaires.gob.ar/evento/e1281314-a634-47a0-a2fa-89f0c3c88b0b, https://complejoteatral.gob.ar/ver/buenas-palabras, https://entradasba.buenosaires.gob.ar/evento/67826298-9dd3-4680-bf3f-d3d652a513c0, https://complejoteatral.gob.ar/ver/chau-macoco, https://complejoteatral.gob.ar/ver/jazz_buenos_aires, https://complejoteatral.gob.ar/ver/festival_el_tornillo, https://complejoteatral.gob.ar/ver/MILONGA-EN-EL-HALL, https://complejoteatral.gob.ar/ver/milonga_en_el_plata, https://complejoteatral.gob.ar/ver/boleslaw-senderowicz, https://entradasba.buenosaires.gob.ar/evento/b1e874ee-2bed-4b60-886b-2fb3ff16cbf5, https://complejoteatral.gob.ar/ver/La-semana-de-los-muertos-vivos, https://complejoteatral.gob.ar/pdf/la-semana-de-los-muertos-vivos.pdf, https://entradasba.buenosaires.gob.ar/evento/56560ce9-5a8d-425d-b927-242b1f96b1c1, https://complejoteatral.gob.ar/ver/Tardes-de-soledad, https://complejoteatral.gob.ar/pdf/programa-tardes-de-soledad.pdf, https://entradasba.buenosaires.gob.ar/evento/8d95c637-802f-4f2a-95bc-c4cb9b4a7459, https://complejoteatral.gob.ar/ver/Semana-de-los-Premios-Goya-en-Buenos-Aires, https://complejoteatral.gob.ar/pdf/semana-de-los-premios-goya-en-buenos-aires.pdf, https://entradasba.buenosaires.gob.ar/evento/18bbe55b-23d0-4526-a64f-be6ba06afa35, https://complejoteatral.gob.ar/ver/ Cinemateca-abierta, https://complejoteatral.gob.ar/pdf/programa-cinemateca-abierta-2026.pdf, https://complejoteatral.gob.ar/ver/Cien-años-atrás:-aventuras-y-romance, https://complejoteatral.gob.ar/pdf/programa-cien-anos-atras-2026.pdf, https://complejoteatral.gob.ar/ver/Nicolás-Pereda:-el-pensamiento-en-acción, https://complejoteatral.gob.ar/ver/En-el-cine, https://www.paseolaplaza.com.ar/obra/queridisimo-truman]
# https://malba.org.ar/                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [https://malba.org.ar/agenda-hoy/, https://malba.org.ar/eventos/sobre/virtual/, https://malba.org.ar/evento/tercer-ojo__coleccion-costantini_en-malba/, https://malba.org.ar/evento/margarita-paksa-ideas-correspondientes-1964-1984/, https://malba.org.ar/evento/olga-de-amaral-cuerpo-textil/, https://malba.org.ar/evento/fernanda-laguna-mi-corazon-es-un-iman/, https://malba.org.ar/evento/cuerpo-textil/, https://malba.org.ar/evento/borges-entre-el-tiempo-y-la-eternidad/, https://malba.org.ar/evento/visitas-guiadas__recorridos-abiertos-por-tercer-ojo/, https://malba.org.ar/evento/margarita-x-margarita-textos-hablados-textos-escritos/, https://malba.org.ar/evento/recorrido-en-lsa-por-tercer-ojo/, https://malba.org.ar/evento/the-souffleur/, https://malba.org.ar/evento/weser/, https://malba.org.ar/evento/un-cabo-suelto/, https://malba.org.ar/evento/caripelas-de-coleccion/, https://malba.org.ar/evento/el-limite-de-lo-humano-virginia-woolf-stanislaw-lem-haruki-murakami-y-w-g-sebald/, https://malba.org.ar/evento/recorridos-abiertos-por-pop-brasil-vanguardia-y-nueva-figuracion-1960s-70s/, https://malba.org.ar/evento/micro-mediaciones__margarita-paksa-ideas-correspondientes-1964-1984/, https://malba.org.ar/evento/ls83/]
# https://www.bellasartes.gob.ar/agenda/                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [https://www.bellasartes.gob.ar/agenda/, https://www.bellasartes.gob.ar/lang/pt/?path=/agenda/, https://www.bellasartes.gob.ar/lang/en/?path=/agenda/, https://www.bellasartes.gob.ar/agenda/2026/2/3/, https://www.bellasartes.gob.ar/agenda/2026/3/5/, https://www.bellasartes.gob.ar/agenda/circulacion-en-planta-baja-con-sentido-unico/, https://www.bellasartes.gob.ar/agenda/visit-egipto/, https://www.bellasartes.gob.ar/agenda/rituales-egipto/, https://www.bellasartes.gob.ar/agenda/arte-arg1/, https://www.bellasartes.gob.ar/agenda/exp-egipto/, https://www.bellasartes.gob.ar/agenda/premio-25/, https://www.bellasartes.gob.ar/agenda/dibujo-egipto/, https://www.bellasartes.gob.ar/agenda/letras-egipt/, https://www.bellasartes.gob.ar/agenda/desafios-sigloxx/, https://www.bellasartes.gob.ar/agenda/recorrido-por-la-planta-baja-y-primer-piso/, https://www.bellasartes.gob.ar/agenda/visit-egipto-2/, https://www.bellasartes.gob.ar/agenda/azull/, https://www.bellasartes.gob.ar/agenda/encuentro-literatura/, https://www.bellasartes.gob.ar/agenda/lsa-egipto/, https://www.bellasartes.gob.ar/agenda/guardar-como/]
# https://www.teatrocervantes.gob.ar/                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [https://www.teatrocervantes.gob.ar/proximamente/, https://www.teatrocervantes.gob.ar/obra/el-retrato-punzo-2/, https://www.teatrocervantes.gob.ar/obra/los-dias-perfectos/, https://www.teatrocervantes.gob.ar/obra/la-revista-del-cervantes-3/, https://www.teatrocervantes.gob.ar/calendario/, https://www.teatrocervantes.gob.ar/obra/el-avido-espectador/, https://www.teatrocervantes.gob.ar/programacion/]
# Name: event_url, dtype: object

# %%
# transform grouped into payloads - its a more efficient way to pass the data to the LLM

payloads = [
    {"homepage_url": page_url, "institution": None, "links": links}
    for page_url, links in grouped.items()
]

import json
payload_json_links = json.dumps(payloads, ensure_ascii=False, indent=2)
payload_json_links
# Out:
# '[\n  {\n    "homepage_url": "https://complejoteatral.gob.ar/",\n    "institution": null,\n    "links": [\n      "https://complejoteatral.gob.ar/agenda?fecha=18-02-2026",\n      "https://complejoteatral.gob.ar/pdf/temporada2026.pdf",\n      "https://complejoteatral.gob.ar/ver/visitas_guiadas_al_teatro_san_martín",\n      "https://complejoteatral.gob.ar/ver/la_gaviota",\n      "https://entradasba.buenosaires.gob.ar/evento/d90f82ed-ec8f-46cf-b8b2-48e665a36fc3",\n      "https://complejoteatral.gob.ar/ver/los-pilares-de-la-sociedad",\n      "https://entradasba.buenosaires.gob.ar/evento/42523311-973e-4a52-b2ee-63a59c48a2b7",\n      "https://complejoteatral.gob.ar/ver/baco-polaco",\n      "https://entradasba.buenosaires.gob.ar/evento/f94c1c9a-151e-49a8-8ed8-c9aa9d0464c3",\n      "https://complejoteatral.gob.ar/ver/invasiones-1",\n      "https://entradasba.buenosaires.gob.ar/evento/e1281314-a634-47a0-a2fa-89f0c3c88b0b",\n      "https://complejoteatral.gob.ar/ver/buenas-palabras",\n      "https://entradasba.buenosaires.gob.ar/evento/67826298-9dd3-4680-bf3f-d3d652a513c0",\n      "https://complejoteatral.gob.ar/ver/chau-macoco",\n      "https://complejoteatral.gob.ar/ver/jazz_buenos_aires",\n      "https://complejoteatral.gob.ar/ver/festival_el_tornillo",\n      "https://complejoteatral.gob.ar/ver/MILONGA-EN-EL-HALL",\n      "https://complejoteatral.gob.ar/ver/milonga_en_el_plata",\n      "https://complejoteatral.gob.ar/ver/boleslaw-senderowicz",\n      "https://entradasba.buenosaires.gob.ar/evento/b1e874ee-2bed-4b60-886b-2fb3ff16cbf5",\n      "https://complejoteatral.gob.ar/ver/La-semana-de-los-muertos-vivos",\n      "https://complejoteatral.gob.ar/pdf/la-semana-de-los-muertos-vivos.pdf",\n      "https://entradasba.buenosaires.gob.ar/evento/56560ce9-5a8d-425d-b927-242b1f96b1c1",\n      "https://complejoteatral.gob.ar/ver/Tardes-de-soledad",\n      "https://complejoteatral.gob.ar/pdf/programa-tardes-de-soledad.pdf",\n      "https://entradasba.buenosaires.gob.ar/evento/8d95c637-802f-4f2a-95bc-c4cb9b4a7459",\n      "https://complejoteatral.gob.ar/ver/Semana-de-los-Premios-Goya-en-Buenos-Aires",\n      "https://complejoteatral.gob.ar/pdf/semana-de-los-premios-goya-en-buenos-aires.pdf",\n      "https://entradasba.buenosaires.gob.ar/evento/18bbe55b-23d0-4526-a64f-be6ba06afa35",\n      "https://complejoteatral.gob.ar/ver/ Cinemateca-abierta",\n      "https://complejoteatral.gob.ar/pdf/programa-cinemateca-abierta-2026.pdf",\n      "https://complejoteatral.gob.ar/ver/Cien-años-atrás:-aventuras-y-romance",\n      "https://complejoteatral.gob.ar/pdf/programa-cien-anos-atras-2026.pdf",\n      "https://complejoteatral.gob.ar/ver/Nicolás-Pereda:-el-pensamiento-en-acción",\n      "https://complejoteatral.gob.ar/ver/En-el-cine",\n      "https://www.paseolaplaza.com.ar/obra/queridisimo-truman"\n    ]\n  },\n  {\n    "homepage_url": "https://malba.org.ar/",\n    "institution": null,\n    "links": [\n      "https://malba.org.ar/agenda-hoy/",\n      "https://malba.org.ar/eventos/sobre/virtual/",\n      "https://malba.org.ar/evento/tercer-ojo__coleccion-costantini_en-malba/",\n      "https://malba.org.ar/evento/margarita-paksa-ideas-correspondientes-1964-1984/",\n      "https://malba.org.ar/evento/olga-de-amaral-cuerpo-textil/",\n      "https://malba.org.ar/evento/fernanda-laguna-mi-corazon-es-un-iman/",\n      "https://malba.org.ar/evento/cuerpo-textil/",\n      "https://malba.org.ar/evento/borges-entre-el-tiempo-y-la-eternidad/",\n      "https://malba.org.ar/evento/visitas-guiadas__recorridos-abiertos-por-tercer-ojo/",\n      "https://malba.org.ar/evento/margarita-x-margarita-textos-hablados-textos-escritos/",\n      "https://malba.org.ar/evento/recorrido-en-lsa-por-tercer-ojo/",\n      "https://malba.org.ar/evento/the-souffleur/",\n      "https://malba.org.ar/evento/weser/",\n      "https://malba.org.ar/evento/un-cabo-suelto/",\n      "https://malba.org.ar/evento/caripelas-de-coleccion/",\n      "https://malba.org.ar/evento/el-limite-de-lo-humano-virgin ...

# %% [markdown]
# ## Step 1. Use LLM to pick relevant links
#
# ### We will call an LLM so it picks only relevant links with events
#
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding - hard coding each scenario would take us quite some time.

# %%
link_system_prompt = """
You are selecting event-related links for a Buenos Aires cultural events scraper.

You will receive a JSON object as input with keys:
- homepage_url: string
- institution: string or null
- links: array of absolute URLs (strings)

Your job:
- Pick ONLY links that are relevant for finding current/upcoming cultural events (agenda/listings, event detail pages, ticket purchase pages, program PDFs, calendars).
- Exclude terms/privacy, contact/about, donations/sponsors, newsletters, login, generic navigation, accessibility pages, and any social media.
- Do NOT invent new URLs. Every returned URL must come from input.links.
- Return at most 30 links.

Return ONLY valid JSON (no markdown, no prose) with this schema:

{
  "homepage_url": "<string>",
  "institution": "<string or null>",
  "links": [
    {
      "url": "<string>"
    }
  ]
}
"""

# %%
def get_links_user_prompt(payload_json_links):
    user_prompt = f"""
Here is the list of links on the website in json format: {payload_json_links} -
Please decide which of these are relevant web links for a brochure listing current cultural
evens in Buenos Aires.
Do not include Terms of Service, Privacy, email, social media links, or general descriptions of the theater that´s not related to any event.

Links (some might be relative links):

"""
    links = fetch_website_links(payload_json_links)
    user_prompt += "\n".join(links)
    return user_prompt

# %%
def select_relevant_links(payload_json_links):
    print(f"Selecting relevant links for {payload_json_links} by calling {MODEL}")
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": payload_json_links}
        ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    links = json.loads(result)
    print(f"Found {len(links['links'])} relevant links")
    return links

# %%
outs = [select_relevant_links(p) for p in payloads]  # payloads is list of dicts or json strings

df_selected = pd.concat(
    [pd.DataFrame(o["links"]).assign(homepage_url=o.get("homepage_url"), institution=o.get("institution"))
     for o in outs],
    ignore_index=True
)

df_selected
# Out:
# Selecting relevant links for {'homepage_url': 'https://complejoteatral.gob.ar/', 'institution': None, 'links': ['https://complejoteatral.gob.ar/agenda?fecha=18-02-2026', 'https://complejoteatral.gob.ar/pdf/temporada2026.pdf', 'https://complejoteatral.gob.ar/ver/visitas_guiadas_al_teatro_san_martín', 'https://complejoteatral.gob.ar/ver/la_gaviota', 'https://entradasba.buenosaires.gob.ar/evento/d90f82ed-ec8f-46cf-b8b2-48e665a36fc3', 'https://complejoteatral.gob.ar/ver/los-pilares-de-la-sociedad', 'https://entradasba.buenosaires.gob.ar/evento/42523311-973e-4a52-b2ee-63a59c48a2b7', 'https://complejoteatral.gob.ar/ver/baco-polaco', 'https://entradasba.buenosaires.gob.ar/evento/f94c1c9a-151e-49a8-8ed8-c9aa9d0464c3', 'https://complejoteatral.gob.ar/ver/invasiones-1', 'https://entradasba.buenosaires.gob.ar/evento/e1281314-a634-47a0-a2fa-89f0c3c88b0b', 'https://complejoteatral.gob.ar/ver/buenas-palabras', 'https://entradasba.buenosaires.gob.ar/evento/67826298-9dd3-4680-bf3f-d3d652a513c0', 'https://complejoteatral.gob.ar/ver/chau-macoco', 'https://complejoteatral.gob.ar/ver/jazz_buenos_aires', 'https://complejoteatral.gob.ar/ver/festival_el_tornillo', 'https://complejoteatral.gob.ar/ver/MILONGA-EN-EL-HALL', 'https://complejoteatral.gob.ar/ver/milonga_en_el_plata', 'https://complejoteatral.gob.ar/ver/boleslaw-senderowicz', 'https://entradasba.buenosaires.gob.ar/evento/b1e874ee-2bed-4b60-886b-2fb3ff16cbf5', 'https://complejoteatral.gob.ar/ver/La-semana-de-los-muertos-vivos', 'https://complejoteatral.gob.ar/pdf/la-semana-de-los-muertos-vivos.pdf', 'https://entradasba.buenosaires.gob.ar/evento/56560ce9-5a8d-425d-b927-242b1f96b1c1', 'https://complejoteatral.gob.ar/ver/Tardes-de-soledad', 'https://complejoteatral.gob.ar/pdf/programa-tardes-de-soledad.pdf', 'https://entradasba.buenosaires.gob.ar/evento/8d95c637-802f-4f2a-95bc-c4cb9b4a7459', 'https://complejoteatral.gob.ar/ver/Semana-de-los-Premios-Goya-en-Buenos-Aires', 'https://complejoteatral.gob.ar/pdf/semana-de-los-premios-goya-en-buenos-aires.pdf', 'https://entradasba.buenosaires.gob.ar/evento/18bbe55b-23d0-4526-a64f-be6ba06afa35', 'https://complejoteatral.gob.ar/ver/ Cinemateca-abierta', 'https://complejoteatral.gob.ar/pdf/programa-cinemateca-abierta-2026.pdf', 'https://complejoteatral.gob.ar/ver/Cien-años-atrás:-aventuras-y-romance', 'https://complejoteatral.gob.ar/pdf/programa-cien-anos-atras-2026.pdf', 'https://complejoteatral.gob.ar/ver/Nicolás-Pereda:-el-pensamiento-en-acción', 'https://complejoteatral.gob.ar/ver/En-el-cine', 'https://www.paseolaplaza.com.ar/obra/queridisimo-truman']} by calling gpt-5-nano
# Found 34 relevant links
# Selecting relevant links for {'homepage_url': 'https://malba.org.ar/', 'institution': None, 'links': ['https://malba.org.ar/agenda-hoy/', 'https://malba.org.ar/eventos/sobre/virtual/', 'https://malba.org.ar/evento/tercer-ojo__coleccion-costantini_en-malba/', 'https://malba.org.ar/evento/margarita-paksa-ideas-correspondientes-1964-1984/', 'https://malba.org.ar/evento/olga-de-amaral-cuerpo-textil/', 'https://malba.org.ar/evento/fernanda-laguna-mi-corazon-es-un-iman/', 'https://malba.org.ar/evento/cuerpo-textil/', 'https://malba.org.ar/evento/borges-entre-el-tiempo-y-la-eternidad/', 'https://malba.org.ar/evento/visitas-guiadas__recorridos-abiertos-por-tercer-ojo/', 'https://malba.org.ar/evento/margarita-x-margarita-textos-hablados-textos-escritos/', 'https://malba.org.ar/evento/recorrido-en-lsa-por-tercer-ojo/', 'https://malba.org.ar/evento/the-souffleur/', 'https://malba.org.ar/evento/weser/', 'https://malba.org.ar/evento/un-cabo-suelto/', 'https://malba.org.ar/evento/caripelas-de-coleccion/', 'https://malba.org.ar/evento/el-limite-de-lo-humano-virginia-woolf-stanislaw-lem-haruki-murakami-y-w-g-sebald/', 'https://malba.org.ar/evento/recorridos-abiertos-por-pop-brasil-vanguardia-y-nueva-figuracion-1960s-70s/', 'https://malba.org.ar/evento/micro-mediaciones__margarita-paksa-ideas-correspondientes-1964-1984/', 'https://malba.org.ar/evento/ls83/']} by calling gpt-5-nano
# Found 19 relevant links
# Selecting relevant links for {'homepage_url': 'https://www.bellasartes.gob.ar/agenda/', 'institution': None, 'links': ['https://www.bellasartes.gob.ar/agenda/', 'https://www.bellasartes.gob.ar/lang/pt/?path=/agenda/', 'https://www.bellasartes.gob.ar/lang/en/?path=/agenda/', 'https://www.bellasartes.gob.ar/agenda/2026/2/3/', 'https://www.bellasartes.gob.ar/agenda/2026/3/5/', 'https://www.bellasartes.gob.ar/agenda/circulacion-en-planta-baja-con-sentido-unico/', 'https://www.bellasartes.gob.ar/agenda/visit-egipto/', 'https://www.bellasartes.gob.ar/agenda/rituales-egipto/', 'https://www.bellasartes.gob.ar/agenda/arte-arg1/', 'https://www.bellasartes.gob.ar/agenda/exp-egipto/', 'https://www.bellasartes.gob.ar/agenda/premio-25/', 'https://www.bellasartes.gob.ar/agenda/dibujo-egipto/', 'https://www.bellasartes.gob.ar/agenda/letras-egipt/', 'https://www.bellasartes.gob.ar/agenda/desafios-sigloxx/', 'https://www.bellasartes.gob.ar/agenda/recorrido-por-la-planta-baja-y-primer-piso/', 'https://www.bellasartes.gob.ar/agenda/visit-egipto-2/', 'https://www.bellasartes.gob.ar/agenda/azull/', 'https://www.bellasartes.gob.ar/agenda/encuentro-literatura/', 'https://www.bellasartes.gob.ar/agenda/lsa-egipto/', 'https://www.bellasartes.gob.ar/agenda/guardar-como/']} by calling gpt-5-nano
# Found 18 relevant links
# Selecting relevant links for {'homepage_url': 'https://www.teatrocervantes.gob.ar/', 'institution': None, 'links': ['https://www.teatrocervantes.gob.ar/proximamente/', 'https://www.teatrocervantes.gob.ar/obra/el-retrato-punzo-2/', 'https://www.teatrocervantes.gob.ar/obra/los-dias-perfectos/', 'https://www.teatrocervantes.gob.ar/obra/la-revista-del-cervantes-3/', 'https://www.teatrocervantes.gob.ar/calendario/', 'https://www.teatrocervantes.gob.ar/obra/el-avido-espectador/', 'https://www.teatrocervantes.gob.ar/programacion/']} by calling gpt-5-nano
# Found 7 relevant links
#                                                                                                               url  \
# 0                                                          https://complejoteatral.gob.ar/agenda?fecha=18-02-2026
# 1                                                            https://complejoteatral.gob.ar/pdf/temporada2026.pdf
# 2                                                                   https://complejoteatral.gob.ar/ver/la_gaviota
# 3                                                   https://complejoteatral.gob.ar/ver/los-pilares-de-la-sociedad
# 4                                                                  https://complejoteatral.gob.ar/ver/baco-polaco
# 5                                                                 https://complejoteatral.gob.ar/ver/invasiones-1
# 6                                                              https://complejoteatral.gob.ar/ver/buenas-palabras
# 7                                                                  https://complejoteatral.gob.ar/ver/chau-macoco
# 8                                                            https://complejoteatral.gob.ar/ver/jazz_buenos_aires
# 9                                                         https://complejoteatral.gob.ar/ver/festival_el_tornillo
# 10                                                          https://complejoteatral.gob.ar/ver/MILONGA-EN-EL-HALL
# 11                                                         https://complejoteatral.gob.ar/ver/milonga_en_el_plata
# 12                                                        https://complejoteatral.gob.ar/ver/boleslaw-senderowicz
# 13                                              https://complejoteatral.gob.ar/ver/La-semana-de-los-muertos-vivos
# 14                                          https://complejoteatral.gob.ar/pdf/la-semana-de-los-muertos-vivos.pdf
# 15                                                           https://complejoteatral.gob.ar/ver/Tardes-de-soledad
# 16                                              https://complejoteatral.gob.ar/pdf/programa-tardes-de-soledad.pdf
# 17                                  https://complejoteatral.gob.ar/ver/Semana-de-los-Premios-Goya-en-Buenos-Aires
# 18                              https://complejoteatral.gob.ar/pdf/semana-de-los-premios-goya-en-buenos-aires.pdf
# 19                                        https://complejoteatral.gob.ar/pdf/programa-cinemateca-abierta-2026.pdf
# 20                                        https://complejoteatral.gob.ar/ver/Cien-años-atrás:-aventuras-y-romance
# 21                                           https://complejoteatral.gob.ar/pdf/programa-cien-anos-atras-2026.pdf
# 22                                    https://complejoteatral.gob.ar/ver/Nicolás-Pereda:-el-pensamiento-en-acción
# 23                                                                  https://complejoteatral.gob.ar/ver/En-el-cine
# 24                                                        https://www.paseolaplaza.com.ar/obra/queridisimo-truman
# 25                              https://entradasba.buenosaires.gob.ar/evento/d90f82ed-ec8f-46cf-b8b2-48e665a36fc3
# 26                              https://entradasba.buenosaires.gob.ar/evento/42523311-973e-4a52-b2ee-63a59c48a2b7
# 27                              https://entradasba.buenosaires.gob.ar/evento/f94c1c9a-151e-49a8-8ed8-c9aa9d0464c3
# 28                              https://entradasba.buenosaires.gob.ar/evento/e1281314-a634-47a0-a2fa-89f0c3c88b0b
# 29                              https://entradasba.buenosaires.gob.ar/evento/67826298-9dd3-4680-bf3f-d3d652a513c0
# 30                              https://entradasba.buenosaires.gob.ar/evento/b1e874ee-2bed-4b60-886b-2fb3ff16cbf5
# 31                              https://entradasba.buenosaires.gob.ar/evento/56560ce9-5a8d-425d-b927-242b1f96b1c1
# 32                              https://entradasba.buenosaires.gob.ar/evento/8d95c637-802f-4f2a-95bc-c4cb9b4a7459
# 33                              https://entradasba.buenosaires.gob.ar/evento/18bbe55b-23d0-4526-a64f-be6ba06afa35
# 34                                                                               https://malba.org.ar/agenda-hoy/
# 35                                                                    https://malba.org.ar/eventos/sobre/virtual/
# 36                                         https://malba.org.ar/evento/tercer-ojo__coleccion-costantini_en-malba/
# 37                                  https://malba.org.ar/evento/margarita-paksa-ideas-correspondientes-1964-1984/
# 38                                                      https://malba.org.ar/evento/olga-de-amaral-cuerpo-textil/
# 39                                             https://malba.org.ar/evento/fernanda-laguna-mi-corazon-es-un-iman/
# 40                                                                     https://malba.org.ar/evento/cuerpo-textil/
# 41                                             https://malba.org.ar/evento/borges-entre-el-tiempo-y-la-eternidad/
# 42                               https://malba.org.ar/evento/visitas-guiadas__recorridos-abiertos-por-tercer-ojo/
# 43                             https://malba.org.ar/evento/margarita-x-margarita-textos-hablados-textos-escritos/
# 44                                                   https://malba.org.ar/evento/recorrido-en-lsa-por-tercer-ojo/
# 45                                                                     https://malba.org.ar/evento/the-souffleur/
# 46                                                                             https://malba.org.ar/evento/weser/
# 47                                                                    https://malba.org.ar/evento/un-cabo-suelto/
# 48                                                            https://malba.org.ar/evento/caripelas-de-coleccion/
# 49  https://malba.org.ar/evento/el-limite-de-lo-humano-virginia-woolf-stanislaw-lem-haruki-murakami-y-w-g-sebald/
# 50        https://malba.org.ar/evento/recorridos-abiertos-por-pop-brasil-vanguardia-y-nueva-figuracion-1960s-70s/
# 51               https://malba.org.ar/evento/micro-mediaciones__margarita-paksa-ideas-correspondientes-1964-1984/
# 52                                                                              https://malba.org.ar/evento/ls83/
# 53                                                                         https://www.bellasartes.gob.ar/agenda/
# 54                                                          https://www.bellasartes.gob.ar/lang/pt/?path=/agenda/
# 55                                                          https://www.bellasartes.gob.ar/lang/en/?path=/agenda/
# 56                                                                https://www.bellasartes.gob.ar/agenda/2026/2/3/
# 57                                                                https://www.bellasartes.gob.ar/agenda/2026/3/5/
# 58                                                            https://www.bellasartes.gob.ar/agenda/visit-egipto/
# 59                                                         https://www.bellasartes.gob.ar/agenda/rituales-egipto/
# 60                                                              https://www.bellasartes.gob.ar/agenda/exp-egipto/
# 61                                                           https://www.bellasartes.gob.ar/agenda/dibujo-egipto/
# 62                                                            https://www.bellasartes.gob.ar/agenda/letras-egipt/
# 63                                                        https://www.bellasartes.gob.ar/agenda/desafios-sigloxx/
# 64                              https://www.bellasartes.gob.ar/agenda/recorrido-por-la-planta-baja-y-primer-piso/
# 65                                                          https://www.bellasartes.gob.ar/agenda/visit-egipto-2/
# 66                                                                   https://www.bellasartes.gob.ar/agenda/azull/
# 67                                                    https://www.bellasartes.gob.ar/agenda/encuentro-literatura/
# 68                                                              https://www.bellasartes.gob.ar/agenda/lsa-egipto/
# 69                                                               https://www.bellasartes.gob.ar/agenda/premio-25/
# 70                                                               https://www.bellasartes.gob.ar/agenda/arte-arg1/
# 71                                                               https://www.teatrocervantes.gob.ar/proximamente/
# 72                                                    https://www.teatrocervantes.gob.ar/obra/el-retrato-punzo-2/
# 73                                                    https://www.teatrocervantes.gob.ar/obra/los-dias-perfectos/
# 74                                            https://www.teatrocervantes.gob.ar/obra/la-revista-del-cervantes-3/
# 75                                                                 https://www.teatrocervantes.gob.ar/calendario/
# 76                                                   https://www.teatrocervantes.gob.ar/obra/el-avido-espectador/
# 77                                                               https://www.teatrocervantes.gob.ar/programacion/
#
#                               homepage_url institution
# 0          https://complejoteatral.gob.ar/        None
# 1          https://complejoteatral.gob.ar/        None
# 2          https://complejoteatral.gob.ar/        None
# 3          https://complejoteatral.gob.ar/        None
# 4          https://complejoteatral.gob.ar/        None
# 5          https://complejoteatral.gob.ar/        None
# 6          https://complejoteatral.gob.ar/        None
# 7          https://complejoteatral.gob.ar/        None
# 8          https://complejoteatral.gob.ar/        None
# 9          https://complejoteatral.gob.ar/        None
# 10         https://complejoteatral.gob.ar/        None
# 11         https://complejoteatral.gob.ar/        None
# 12         https://complejoteatral.gob.ar/        None
# 13         https://complejoteatral.gob.ar/        None
# 14         https://complejoteatral.gob.ar/        None
# 15         https://complejoteatral.gob.ar/        None
# 16         https://complejoteatral.gob.ar/        None
# 17         https://complejoteatral.gob.ar/        None
# 18         https://complejoteatral.gob.ar/        None
# 19         https://complejoteatral.gob.ar/        None
# 20         https://complejoteatral.gob.ar/        None
# 21         https://complejoteatral.gob.ar/        None
# 22         https://complejoteatral.gob.ar/        None
# 23         https://complejoteatral.gob.ar/        None
# 24         https://complejoteatral.gob.ar/        None
# 25         https://complejoteatral.gob.ar/        None
# 26         https://complejoteatral.gob.ar/        None
# 27         https://complejoteatral.gob.ar/        None
# 28         https://complejoteatral.gob.ar/        None
# 29         https://complejoteatral.gob.ar/        None
# 30         https://complejoteatral.gob.ar/        None
# 31         https://complejoteatral.gob.ar/        None
# 32         https://complejoteatral.gob.ar/        None
# 33         https://complejoteatral.gob.ar/        None
# 34                   https://malba.org.ar/        None
# 35                   https://malba.org.ar/        None
# 36                   https://malba.org.ar/        None
# 37                   https://malba.org.ar/        None
# 38                   https://malba.org.ar/        None
# 39                   https://malba.org.ar/        None
# 40                   https://malba.org.ar/        None
# 41                   https://malba.org.ar/        None
# 42                   https://malba.org.ar/        None
# 43                   https://malba.org.ar/        None
# 44                   https://malba.org.ar/        None
# 45                   https://malba.org.ar/        None
# 46                   https://malba.org.ar/        None
# 47                   https://malba.org.ar/        None
# 48                   https://malba.org.ar/        None
# 49                   https://malba.org.ar/        None
# 50                   https://malba.org.ar/        None
# 51                   https://malba.org.ar/        None
# 52                   https://malba.org.ar/        None
# 53  https://www.bellasartes.gob.ar/agenda/        None
# 54  https://www.bellasartes.gob.ar/agenda/        None
# 55  https://www.bellasartes.gob.ar/agenda/        None
# 56  https://www.bellasartes.gob.ar/agenda/        None
# 57  https://www.bellasartes.gob.ar/agenda/        None
# 58  https://www.bellasartes.gob.ar/agenda/        None
# 59  https://www.bellasartes.gob.ar/agenda/        None
# 60  https://www.bellasartes.gob.ar/agenda/        None
# 61  https://www.bellasartes.gob.ar/agenda/        None
# 62  https://www.bellasartes.gob.ar/agenda/        None
# 63  https://www.bellasartes.gob.ar/agenda/        None
# 64  https://www.bellasartes.gob.ar/agenda/        None
# 65  https://www.bellasartes.gob.ar/agenda/        None
# 66  https://www.bellasartes.gob.ar/agenda/        None
# 67  https://www.bellasartes.gob.ar/agenda/        None
# 68  https://www.bellasartes.gob.ar/agenda/        None
# 69  https://www.bellasartes.gob.ar/agenda/        None
# 70  https://www.bellasartes.gob.ar/agenda/        None
# 71     https://www.teatrocervantes.gob.ar/        None
# 72     https://www.teatrocervantes.gob.ar/        None
# 73     https://www.teatrocervantes.gob.ar/        None
# 74     https://www.teatrocervantes.gob.ar/        None
# 75     https://www.teatrocervantes.gob.ar/        None
# 76     https://www.teatrocervantes.gob.ar/        None
# 77     https://www.teatrocervantes.gob.ar/        None

# %% [markdown]
# ## Second step: lets classify those links
#
# Assemble all the details into another prompt to GPT-5-nano

# %%
def fetch_page_and_all_relevant_links(payload_json_links):
    contents = fetch_website_contents(payload_json_links)
    relevant_links = select_relevant_links(payload_json_links)
    result = f"## Landing Page:\n\n{contents}\n## Relevant Links:\n"
    for link in relevant_links['links']:
        result += f"\n\n### Link: {link['type']}\n"
        result += fetch_website_contents(link["url"])
    return result

# %%
print(fetch_page_and_all_relevant_links("https://complejoteatral.gob.ar/"))

# %%
brochure_system_prompt = """
You are an assistant that analyzes the contents of several relevant pages from a cultural institution website
and creates a short brochure about the events that are happening in Buenos Aires.
Respond in markdown without code blocks.
Include event name, type, short description, date and time of the event, link to the event if available.
"""

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# brochure_system_prompt = """
# You are an assistant that analyzes the contents of several relevant pages from a company website
# and creates a short, humorous, entertaining, witty brochure about the company for prospective customers, investors and recruits.
# Respond in markdown without code blocks.
# Include details of company culture, customers and careers/jobs if you have the information.
# """

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"""
You are looking at a cultural institution called: {company_name}
Here are the contents of its pages that contain information about current cultural events in Buenos Aires;
use this information to build a short brochure about the events that are happening in Buenos Aires.\n\n
"""
    user_prompt += fetch_page_and_all_relevant_links(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("Teatro San Martín", "https://complejoteatral.gob.ar/")

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model="gpt-4.1-mini",
        messages=[
            {"role": "system", "content": brochure_system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
        ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("Teatro San Martín", "https://complejoteatral.gob.ar/")

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model="gpt-4.1-mini",
        messages=[
            {"role": "system", "content": brochure_system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        update_display(Markdown(response), display_id=display_handle.display_id)
